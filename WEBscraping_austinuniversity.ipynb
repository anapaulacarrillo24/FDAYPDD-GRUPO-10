# %%
import zipfile

with zipfile.ZipFile('APIs Ejemplos (1).zip', 'r') as zip_ref:
    zip_ref.extractall('APIs Ejemplos (1)')

# %%
import os
os.listdir()
# Out:
# ['.anaconda',
#  '.conda',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.spyder-py3',
#  '3D Objects',
#  'anaconda3',
#  'APIs .ipynb',
#  'APIs Ejemplos (1)',
#  'APIs Ejemplos (1).zip',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NEXT_Webscraping_2 Codigo',
#  'NEXT_Webscraping_2 Codigo (1).zip',
#  'NEXT_Webscraping_Codigo',
#  'NEXT_Webscraping_Codigo.zip',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{8a4e3575-a52f-11ed-ae73-e848b8c82000}.TxR.0.regtrans-ms',
#  'NTUSER.DAT{8a4e3575-a52f-11ed-ae73-e848b8c82000}.TxR.1.regtrans-ms',
#  'NTUSER.DAT{8a4e3575-a52f-11ed-ae73-e848b8c82000}.TxR.2.regtrans-ms',
#  'NTUSER.DAT{8a4e3575-a52f-11ed-ae73-e848b8c82000}.TxR.blf',
#  'NTUSER.DAT{8a4e3576-a52f-11ed-ae73-e848b8c82000}.TM.blf',
# ...

# %%
import requests
import pandas as pd
import time

# %%
link = "https://www.austincc.edu/campuses/"

# %%
response = requests.get(link)
response.status_code
# Out:
# 403

# %%
import requests

url = "https://www.austincc.edu/campuses"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)

response.status_code
# Out:
# 200

# %%
html = response.text
html
# Out:
# '<!DOCTYPE html>\n<html lang="en-US" prefix="og: https://ogp.me/ns#">\n<head>\n\t<meta charset="UTF-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t<style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>\n\t\n<!-- Google Tag Manager for WordPress by gtm4wp.com -->\n<script data-cfasync="false" data-pagespeed-no-defer>\n\tvar gtm4wp_datalayer_name = "dataLayer";\n\tvar dataLayer = dataLayer || [];\n</script>\n<!-- End Google Tag Manager for WordPress by gtm4wp.com -->\n<!-- Search Engine Optimization by Rank Math - https://rankmath.com/ -->\n<meta name="description" content="Classes close to you. Austin Community College has 11 campuses conveniently located across Central Texas. Every campus offers a variety of classes and support"/>\n<meta name="robots" content="follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large"/>\n<link rel="canonical" href="https://www.austincc.edu/campuses/"
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>
# <!-- Google Tag Manager for WordPress by gtm4wp.com -->
# <script data-cfasync="false" data-pagespeed-no-defer="">
# 	var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
# </script>
# <!-- End Google Tag Manager for WordPress by gtm4wp.com -->
# <!-- Search Engine Optimization by Rank Math - https://rankmath.com/ -->
# <meta content="Classes close to you. Austin Community College has 11 campuses conveniently located across Central Texas. Every campus offers a variety of classes and support" name="description"/>
# <meta content="follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large" name="robots"/>
# ...

# %%
lista_h3 = soup.find_all("h3") 
lista_h3
# Out:
# [<h3 class="card-title" id="card-title-1">Cypress Creek</h3>,
#  <h3 class="card-title" id="card-title-2">Eastview Campus</h3>,
#  <h3 class="card-title" id="card-title-3">Elgin Campus</h3>,
#  <h3 class="card-title" id="card-title-4">Hays Campus</h3>,
#  <h3 class="card-title" id="card-title-5">Highland Campus</h3>,
#  <h3 class="card-title" id="card-title-6">Northridge Campus</h3>,
#  <h3 class="card-title" id="card-title-7">Pinnacle Campus (Closed)</h3>,
#  <h3 class="card-title" id="card-title-8">Rio Grande Campus</h3>,
#  <h3 class="card-title" id="card-title-9">Riverside Campus</h3>,
#  <h3 class="card-title" id="card-title-10">Round Rock Campus</h3>,
#  <h3 class="card-title" id="card-title-11">San Gabriel Campus</h3>,
#  <h3 class="card-title" id="card-title-12">South Austin Campus</h3>]

# %%
len(lista_h3)
# Out:
# 12

# %%
campus_austin = []    # obtner lista de cuantos campus existen 
for elemento in lista_h3:
    campus_austin.append(elemento.get_text())
campus_austin
# Out:
# ['Cypress Creek',
#  'Eastview Campus',
#  'Elgin Campus',
#  'Hays Campus',
#  'Highland Campus',
#  'Northridge Campus',
#  'Pinnacle Campus (Closed)',
#  'Rio Grande Campus',
#  'Riverside Campus',
#  'Round Rock Campus',
#  'San Gabriel Campus',
#  'South Austin Campus']

# %%
pip install requests-html
# Out:
# ...
#      -------------------------------------- 83.4/83.4 kB 778.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 201.0/201.0 kB 1.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 78.5/78.5 kB 726.6 kB/s eta 0:00:00
# ...
#      -------------------------------------- 101.4/101.4 kB 2.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.version
# Out:
# '3.7.1 (default, Oct 28 2018, 08:39:03) [MSC v.1912 64 bit (AMD64)]'

# %%
conda create -n scraping_env python=3.10
conda activate scraping_env
pip install requests-html
# Out:
#   File "C:\Users\PC\AppData\Local\Temp\ipykernel_12428\4057144902.py", line 1
#     conda create -n scraping_env python=3.10
#                ^
# SyntaxError: invalid syntax

# %%
link2="https://offices.austincc.edu/business-services/procure-to-pay/procurement/advertised-solicitations/"

# %%
import requests

link = "https://offices.austincc.edu/business-services/procure-to-pay/procurement/advertised-solicitations/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

response = requests.get(link, headers=headers)

response.status_code
# Out:
# 200

# %%
response
# Out:
# <Response [200]>

# %%
html_dos= response.text
html_dos
# Out:
# '<!doctype html>\n<!--[if lt IE 7 ]>\n<html class="ie ie6" lang="en-US">\n<![endif]-->\n<!--[if IE 7 ]>\n<html class="ie ie7" lang="en-US">\n  <![endif]-->\n  <!--[if IE 8 ]>\n  <html class="ie ie8" lang="en-US">\n    <![endif]-->\n    <!--[if IE 9 ]>\n    <html class="ie ie9" lang="en-US">\n      <![endif]-->\n      <!--[if (gte IE 10)|!(IE)]><!-->\n      <html lang="en-US">\n        <!--<![endif]-->\n        <head>\n          <meta charset="UTF-8">\n          <meta name="viewport" content="width=device-width, initial-scale=1" />\n          <meta name="google-site-verification" content="i7vidQMV6sGJQzwm7y8kM0c1c0uLKjDbQ2yYy7QOokg" />\n          <meta name="facebook-domain-verification" content="94lu77slbm0kx7vsp5vv2k4f0avj3s" />\n          <title>Advertised Solicitations | Business Services | Austin Community College District</title>\n          <link rel="profile" href="https://gmpg.org/xfn/11">\n          <link rel="pingback" href="https://offices.austincc.edu/business-services/xml
# ...

# %%
from bs4 import BeautifulSoup
import requests

soup_2 = BeautifulSoup(html_dos, 'html.parser')
soup_2
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7 ]>
# <html class="ie ie6" lang="en-US">
# <![endif]-->
# <!--[if IE 7 ]>
# <html class="ie ie7" lang="en-US">
#   <![endif]-->
# <!--[if IE 8 ]>
#   <html class="ie ie8" lang="en-US">
#     <![endif]-->
# <!--[if IE 9 ]>
#     <html class="ie ie9" lang="en-US">
#       <![endif]-->
# <!--[if (gte IE 10)|!(IE)]><!-->
# <html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <meta content="i7vidQMV6sGJQzwm7y8kM0c1c0uLKjDbQ2yYy7QOokg" name="google-site-verification"/>
# <meta content="94lu77slbm0kx7vsp5vv2k4f0avj3s" name="facebook-domain-verification"/>
# <title>Advertised Solicitations | Business Services | Austin Community College District</title>
# <link href="https://gmpg.org/xfn/11" rel="profile"/>
# <link href="https://offices.austincc.edu/business-services/xmlrpc.php" rel="pingback"/>
# <!--Edit Permissions Check -->
# <!-- Favicons -->
# ...

# %%
html_table = soup_2.find("table", {"id": "tablepress-1"})

# %%
html_table
# Out:
# <table class="tablepress tablepress-id-1 tablepress-responsive" id="tablepress-1">
# <thead>
# <tr class="row-1">
# <th class="column-1">Issue Date</th><th class="column-2">Solicitation</th><th class="column-3">Solicitation Contact</th><th class="column-4">Submission Deadline (Must be received by noon CT, unless otherwise noted)</th><th class="column-5">Status</th>
# </tr>
# </thead>
# <tbody class="row-striping row-hover">
# <tr class="row-2">
# <td class="column-1">01/16/2026</td><td class="column-2"><strong>REQUEST FOR PROPOSALS (RFP)</strong><br/>
# District-Wide Commercial Water Delivery Systems Repair Services and Parts, Indefinite<br/>
# Delivery, Indefinite Quantity (IDIQ)<br/>
# <a href="https://us.workdayspend.com/rfps/public/1043329"> #890-26-264-00-S-JG-RFP</a><br/>
# SOLICTATION CONFERENCE<br/>
# ACC will host an optional virtual solicitation conference on Wednesday, Febuary 4, 2026 at 1:30<br/>
# ...

# %%
html_pretty = html_table.prettify()
print(html_pretty)
# Out:
# <table class="tablepress tablepress-id-1 tablepress-responsive" id="tablepress-1">
#  <thead>
#   <tr class="row-1">
#    <th class="column-1">
#     Issue Date
#    </th>
#    <th class="column-2">
#     Solicitation
#    </th>
#    <th class="column-3">
#     Solicitation Contact
#    </th>
#    <th class="column-4">
#     Submission Deadline (Must be received by noon CT, unless otherwise noted)
#    </th>
#    <th class="column-5">
#     Status
#    </th>
#   </tr>
#  </thead>
#  <tbody class="row-striping row-hover">
#   <tr class="row-2">
#    <td class="column-1">
#     01/16/2026
#    </td>
#    <td class="column-2">
#     <strong>
#      REQUEST FOR PROPOSALS (RFP)
#     </strong>
#     <br/>
#     District-Wide Commercial Water Delivery Systems Repair Services and Parts, Indefinite
#     <br/>
#     Delivery, Indefinite Quantity (IDIQ)
#     <br/>
#     <a href="https://us.workdayspend.com/rfps/public/1043329">
#      #890-26-264-00-S-JG-RFP
#     </a>
#     <br/>
# ...

# %%
import pandas as pd

df2 = pd.read_html(html_pretty)[0]
df2
# Out:
#      Issue Date  \
# 0    01/16/2026
# 1    01/15/2026
# 2    12/17/2025
# 3    12/15/2025
# 4     9/19/2025
# ..          ...
# 166  11/17/2022
# 167  12/01/2022
# 168  12/15/2022
# 169  01/18/2023
# 170  12/21/2022
#
# ...

# %%
import requests
URL_3="https://www.austincc.edu/campuses/cypress-creek/"

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_3, headers=headers)

responses.status_code
# Out:
# 200

# %%
htlm_3=responses.text
htlm_3
# Out:
# '<!DOCTYPE html>\n<html lang="en-US" prefix="og: https://ogp.me/ns#">\n<head>\n\t<meta charset="UTF-8" />\n\t<meta name="viewport" content="width=device-width, initial-scale=1" />\n\t<style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>\n\t\n<!-- Google Tag Manager for WordPress by gtm4wp.com -->\n<script data-cfasync="false" data-pagespeed-no-defer>\n\tvar gtm4wp_datalayer_name = "dataLayer";\n\tvar dataLayer = dataLayer || [];\n</script>\n<!-- End Google Tag Manager for WordPress by gtm4wp.com -->\n<!-- Search Engine Optimization by Rank Math - https://rankmath.com/ -->\n<meta name="description" content="Cypress Creek Campus is nestled among the trees and trails in Cedar Park, just north of Austin. Enjoy shady breezeways and a laid-back campus experience in"/>\n<meta name="robots" content="follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large"/>\n<link rel="canonical" href="https://www.austincc.edu/campuses/cypr
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
soup_3 = BeautifulSoup(htlm_3, 'html.parser')
soup_3
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US" prefix="og: https://ogp.me/ns#">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style>img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }</style>
# <!-- Google Tag Manager for WordPress by gtm4wp.com -->
# <script data-cfasync="false" data-pagespeed-no-defer="">
# 	var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
# </script>
# <!-- End Google Tag Manager for WordPress by gtm4wp.com -->
# <!-- Search Engine Optimization by Rank Math - https://rankmath.com/ -->
# <meta content="Cypress Creek Campus is nestled among the trees and trails in Cedar Park, just north of Austin. Enjoy shady breezeways and a laid-back campus experience in" name="description"/>
# <meta content="follow, index, max-snippet:-1, max-video-preview:-1, max-image-preview:large" name="robots"/>
# ...

# %%
html_table_2 = soup_3.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_2.text
# Out:
# '\n\nContact\n\n1555 Cypress Creek Rd.Cedar Park, TX 78613512-223-2000Map\n'

# %%
clean_text_Cypress = html_table_2.get_text(strip=True)  # extraer contacto 1 
print(clean_text_Cypress)

map_url_Cypress = html_table_2.find("a", href=True).get("href")
print(map_url_Cypress)
# Out:
# Contact1555 Cypress Creek Rd.Cedar Park, TX 78613512-223-2000Map
# https://maps.app.goo.gl/Li7afbkCQZdijV9t9

# %%
import requests  # extrar  contacto 2
URL_4="https://www.austincc.edu/campuses/eastview-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_4, headers=headers)

responses.status_code

htlm_4=responses.text
htlm_4

soup_4 = BeautifulSoup(htlm_4, 'html.parser')
soup_4

html_table_3 = soup_4.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_3.text

clean_text_eastview = html_table_3.get_text(strip=True)  
print(clean_text_eastview)

map_url_eastview = html_table_3.find("a", href=True).get("href")
print(map_url_eastview)
# Out:
# Contact3401 Webberville RoadAustin, Texas 78702512-223-5100Map
# https://maps.app.goo.gl/mnwBhKYZ2v39MUPi6

# %%
import requests  # extrar  contacto 2
URL_5="https://www.austincc.edu/campuses/eastview-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_5, headers=headers)

responses.status_code

htlm_4=responses.text
htlm_4

soup_4 = BeautifulSoup(htlm_4, 'html.parser')
soup_4

html_table_3 = soup_4.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_3.text

clean_text_eastview = html_table_3.get_text(strip=True)  
print(clean_text_eastview)
# Out:
# Contact3401 Webberville RoadAustin, Texas 78702512-223-5100Map

# %%
import requests  # extrar  contacto 3
URL_6="https://www.austincc.edu/campuses/elgin-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_6, headers=headers)

responses.status_code

htlm_5=responses.text
htlm_5

soup_5 = BeautifulSoup(htlm_5, 'html.parser')
soup_5

html_table_4 = soup_5.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_4.text

clean_text_elgin = html_table_4.get_text(strip=True)  
print(clean_text_elgin)

map_url_elgin = html_table_4.find("a", href=True).get("href")
print(map_url_elgin)
# Out:
# Contact1501 West U.S. Hwy. 290Elgin, Texas 78621512-223-9400Map
# https://maps.app.goo.gl/ksyGWKCbQzx9XXNS8

# %%
import requests  # extrar  contacto 4
URL_7="https://www.austincc.edu/campuses/hays-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_7, headers=headers)

responses.status_code

htlm_6=responses.text
htlm_6

soup_6 = BeautifulSoup(htlm_6, 'html.parser')
soup_6

html_table_5 = soup_6.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_5.text

clean_text_hays = html_table_5.get_text(strip=True)  
print(clean_text_hays)

map_url_hays = html_table_5.find("a", href=True).get("href")
print(map_url_hays)
# Out:
# Contact1200 Kohlers CrossingKyle, TX 78640512-262-6500Map
# https://maps.app.goo.gl/kwVU8dci8PLBm36P8

# %%
import requests  # extrar  contacto 5
URL_8="https://www.austincc.edu/campuses/highland-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_8, headers=headers)

responses.status_code

htlm_7=responses.text
htlm_7

soup_7 = BeautifulSoup(htlm_7, 'html.parser')
soup_7

html_table_6 = soup_7.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_6.text

clean_text_highland = html_table_6.get_text(strip=True)  
print(clean_text_highland)

map_url_highland = html_table_6.find("a", href=True).get("href")
print(map_url_highland)
# Out:
# Contact6101 Highland Campus Dr.Austin, TX 78752512-223-7300Map
# https://maps.app.goo.gl/rJLsbztf77pqzNsV7

# %%
import requests  # extrar  contacto 7
URL_9="https://www.austincc.edu/campuses/northridge-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_9, headers=headers)

responses.status_code

htlm_8=responses.text
htlm_8

soup_8 = BeautifulSoup(htlm_8, 'html.parser')
soup_8

html_table_7 = soup_8.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_7.text

clean_text_northridge = html_table_7.get_text(strip=True)  
print(clean_text_northridge)

map_url_northridge = html_table_7.find("a", href=True).get("href")
print(map_url_northridge)
# Out:
# Contact11928 Stonehollow DriveAustin, TX 78758512-223-4000Map
# https://maps.app.goo.gl/YHquaSXbXQCRUeT97

# %%
import requests  # extrar  contacto 10
URL_10="https://www.austincc.edu/campuses/rio-grande-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_10, headers=headers)

responses.status_code

htlm_9=responses.text
htlm_9

soup_9 = BeautifulSoup(htlm_9, 'html.parser')
soup_9

html_table_8 = soup_9.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_8.text

clean_text_rio = html_table_8.get_text(strip=True)  
print(clean_text_rio)

map_url_rio = html_table_8.find("a", href=True).get("href")
print(map_url_rio)
# Out:
# Contact1212 Rio GrandeAustin, TX 78701512-223-3000Map
# https://maps.app.goo.gl/bhkLdBfXmi6vfVVdA

# %%
import requests  # extrar  contacto 11
URL_11="https://www.austincc.edu/campuses/riverside-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_11, headers=headers)

responses.status_code

htlm_10=responses.text
htlm_10

soup_10 = BeautifulSoup(htlm_10, 'html.parser')
soup_10

html_table_9 = soup_10.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_9.text

clean_text_river = html_table_9.get_text(strip=True)  
print(clean_text_river)

map_url_river = html_table_9.find("a", href=True).get("href")
print(map_url_river)
# Out:
# Contact1020 Grove BoulevardAustin, Texas 78741512-223-6100Map
# https://maps.app.goo.gl/6Rytp2cBUvVTeuaR9

# %%
import requests  # extrar  contacto 12
URL_12="https://www.austincc.edu/campuses/round-rock-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_12, headers=headers)

responses.status_code

htlm_11=responses.text
htlm_11

soup_11= BeautifulSoup(htlm_11, 'html.parser')
soup_11

html_table_10 = soup_11.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_10.text

clean_text_round = html_table_10.get_text(strip=True)  
print(clean_text_round)

map_url_round = html_table_10.find("a", href=True).get("href")
print(map_url_round)
# Out:
# Contact4400 College Park DriveRound Rock, TX 78665512-223-0000Map
# https://maps.app.goo.gl/7or1p8WgMdavibm99

# %%
URL_13="https://www.austincc.edu/campuses/san-gabriel-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_13, headers=headers)

responses.status_code

htlm_12=responses.text
htlm_12

soup_12= BeautifulSoup(htlm_12, 'html.parser')
soup_12

html_table_11 = soup_12.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

html_table_11.text

clean_text_sang = html_table_11.get_text(strip=True)  
print(clean_text_sang)

map_url_sang= html_table_11.find("a", href=True).get("href")
print(map_url_sang)
# Out:
# Contact449 San Gabriel Campus Dr.Leander, Texas 78641512-223-2500Map
# https://maps.app.goo.gl/FVVHqCyoDUbzYQNu6

# %%
URL_14="https://www.austincc.edu/campuses/south-austin-campus/"

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/120.0.0.0 Safari/537.36"
}

responses = requests.get(URL_14, headers=headers)

responses.status_code

htlm_13=responses.text
htlm_13

soup_13= BeautifulSoup(htlm_13, 'html.parser')
soup_13

html_table_12 = soup_13.find("div", {"class": "wp-block-group is-layout-flow wp-block-group-is-layout-flow"})

clean_text_saustin = html_table_12.get_text(strip=True)  
print(clean_text_saustin)

map_url_saustin = html_table_12.find("a", href=True).get("href")
print(map_url_saustin)
# Out:
# Contact1820 W. Stassney LaneAustin, TX 78745512-223-9100Map
# https://maps.app.goo.gl/1exD1Txh7A1qMDoLA

# %%
direcciones = []

direcciones.append(clean_text_Cypress)
direcciones.append(clean_text_eastview)
direcciones.append(clean_text_elgin)
direcciones.append(clean_text_hays)
direcciones.append(clean_text_highland)
direcciones.append("CLOSE")
direcciones.append(clean_text_northridge)
direcciones.append(clean_text_rio)
direcciones.append(clean_text_river)
direcciones.append(clean_text_round)
direcciones.append(clean_text_sang)
direcciones.append(clean_text_saustin)

Maps = []

Maps.append(map_url_Cypress)
Maps.append(map_url_eastview)
Maps.append(map_url_elgin)
Maps.append(map_url_hays)
Maps.append(map_url_highland)
Maps.append("CLOSE")
Maps.append(map_url_northridge)
Maps.append(map_url_rio)
Maps.append(map_url_river)
Maps.append(map_url_round)
Maps.append(map_url_sang)
Maps.append(map_url_saustin)

# %%
import pandas as pd

df = pd.DataFrame({
    "Campus": campus_austin,
    "Direccion/ contacto ": direcciones,
    "Link/Maps":Maps
})
pd.set_option('display.max_colwidth', None)

from IPython.display import HTML,display

df["Link/Maps"] = df["Link/Maps"].apply(
    lambda x: f'<a href="{x}" target="_blank">{x}</a>'
)

display(HTML(df.to_html(escape=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Campus</th>
#       <th>Direccion/ contacto</th>
#       <th>Link/Maps</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Cypress Creek</td>
#       <td>1555 Cypress Creek Rd.Cedar Park, TX 78613512-223-2000</td>
#       <td><a href="https://maps.app.goo.gl/Li7afbkCQZdijV9t9" target="_blank">https://maps.app.goo.gl/Li7afbkCQZdijV9t9</a></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Eastview Campus</td>
#       <td>3401 Webberville RoadAustin, Texas 78702512-223-5100</td>
#       <td><a href="https://maps.app.goo.gl/mnwBhKYZ2v39MUPi6" target="_blank">https://maps.app.goo.gl/mnwBhKYZ2v39MUPi6</a></td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Elgin Campus</td>
#       <td>1501 West U.S. Hwy. 290Elgin, Texas 78621512-223-9400</td>
# ...

# %%
clean_text_Cypress= (
    clean_text_Cypress
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)
clean_text_eastview =(
    clean_text_eastview
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)
clean_text_elgin = ( 
    clean_text_elgin
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)
    
    
clean_text_hays=(
    clean_text_hays.replace("Map", "")
    .replace("Contact", "")
    .strip()
)

clean_text_highland = (
    clean_text_highland
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)
clean_text_northridge = (
    clean_text_northridge
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)
clean_text_rio = (
    clean_text_rio
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)

clean_text_river = (
    clean_text_river
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)

clean_text_round = (
    clean_text_round
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)

clean_text_sang = (
    clean_text_sang
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)

clean_text_saustin = (
   clean_text_saustin
    .replace("Map", "")
    .replace("Contact", "")
    .strip()
)
